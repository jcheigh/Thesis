# %%
import os 
import re 
import numpy as np
import ast

MAIN_PATH = os.path.join("/Users", "jcheigh", "Thesis")
DATA_PATH = os.path.join(MAIN_PATH, "data")
path = f"{DATA_PATH}/symmetry/"

def process_list(data_list):
    processed_list = []

    for item in data_list:
        # If the item starts with a '(', consider it a tuple
        if item.startswith('('):
            try:
                # Safely evaluate the item as a tuple
                processed_tuple = ast.literal_eval(item)
                processed_list.append(processed_tuple)
            except ValueError:
                # If there's an error, just append the original string
                processed_list.append(item)
        else:
            try:
                # Convert the item to a float
                processed_list.append(float(item))
            except ValueError:
                # If there's an error, just append the original string
                processed_list.append(item)

    return processed_list


symmetry_dict = {}
def populate_symmetry_dict(path):
    # Regex pattern to extract prime and delta from the filename
    pattern = r"symmetry\(p=(?P<prime>\d+),d=(?P<delta>\d+)\)"

    # List all files in the specified directory
    for filename in os.listdir(path):
        # Match the filename with the regex pattern
        match = re.search(pattern, filename)
        if match:
            prime = int(match.group("prime"))
            delta = int(match.group("delta"))

            # Read the file and get the list of elements
            with open(os.path.join(path, filename), 'r') as file:
                elements = [line.strip() for line in file.readlines()]

            elements = process_list(elements)
            # Update the global dictionary
            symmetry_dict[(prime, delta)] = elements

    return symmetry_dict

symmetry_dict = populate_symmetry_dict(path)

# %%
def get_means():
    means = {}
    for (prime, delta), lst in symmetry_dict.items():
        cons, main = lst[0], lst[1:]
        means[(prime, delta)] = cons * sum(np.prod(term) for term in main)

    return means 
    
means = get_means()

# %%
means
# Out:
# {(562669, 56266): 0.0012155889179929005,
#  (622397, 311198): 2.572020984986534e-06,
#  (584027, 5840): 0.020617215273998284,
#  (714619, 5): 0.00013198525869604044,
#  (508393, 5): 4.50852953988265e-06,
#  (611069, 122213): -0.02198665474155044,
#  (639533, 319766): -4.312136315346918e-06,
#  (635279, 5): 0.00015994968641769907,
#  (739633, 73963): 0.011382661889253798,
#  (639049, 63904): -0.002605954173640314,
#  (544903, 108980): 0.032896496554945774,
#  (611069, 6110): 0.040083600897139963,
#  (671651, 134330): -0.024299052528696928,
#  (643873, 6438): 0.009484973406135327,
#  (635279, 63527): 0.001451981435913041,
#  (673427, 67342): -0.0028375643444399135,
#  (640499, 320249): 5.086863687417395e-06,
#  (511279, 102255): -0.008061141139638324,
#  (537703, 53770): 0.003960038525971556,
#  (643873, 128774): -0.023553965506527493,
#  (611069, 305534): -2.0585374184666566e-05,
#  (544903, 5449): -0.01330084752172934,
#  (635279, 127055): -0.004895013293863854,
#  (544937, 5): -8.07501560151235e-05,
#  (640499, 128099): -0.0023606359114284135,
#  (131687, 65843): -0.00019735385564830023,
#  (639533, 63953): 0.005119876477666774,
#  (624521, 62452): 0.009978117537897476,
#  (593323, 296661): -1.7845048278466676e-05,
#  (555953, 111190): -0.024774482701135185,
#  (714619, 142923): 0.0217165001661593,
#  (582203, 116440): -0.011755556239307977,
#  (526373, 105274): -0.004638488391411855,
#  (121019, 24203): -0.047433860560149296,
#  (582203, 291101): 1.3182083231767478e-05,
#  (544903, 5): 8.669592209350917e-05,
#  (624521, 6245): 0.03189169059525563,
#  (640499, 5): -0.00024772236089818907,
#  (544937, 108987): 0.01349034214298177,
#  (178141, 89070): -5.473625787670674e-05,
#  (643873, 5): 7.176016315832995e-06,
#  (555953, 5): 0.00021932432113543087,
#  (624521, 124904): 0.005378936849692755,
#  (714619, 357309): -1.3209048525386665e-06,
#  (642769, 6427): 0.02596557051037715,
#  (642769, 64276): -0.01573295562350719,
#  (643873, 321936): -3.6119009872085103e-06,
#  (746477, 149295): -0.050959328135394666,
#  (121019, 12101): -0.02514906740895097,
#  (731587, 5): -9.52894846004823e-05,
#  (131687, 1316): 0.02097445478876145,
#  (544937, 272468): -1.7571663356500272e-05,
#  (639049, 127809): -0.024355335469822683,
#  (537703, 268851): 2.1194226410284864e-06,
#  (642769, 321384): -3.839459620420569e-05,
#  (642769, 128553): 0.0231582604263449,
#  (601541, 60154): -0.003965176179207096,
#  (746477, 7464): -0.00848380891586641,
#  (511279, 5): 0.000377072173062135,
#  (639049, 319524): -1.9297520566658812e-05,
#  (739633, 7396): 0.017160650981112593,
#  (555953, 5559): -0.009375502289807975,
#  (673427, 134685): -0.013913397000471672,
#  (546197, 5461): -0.023101028117362758,
#  (178141, 1781): -0.05732578731653979,
#  (601541, 5): -9.548222713583346e-05,
#  (593323, 5): -0.0002741335493976726,
#  (546197, 109239): -0.012727084617969179,
#  (544937, 5449): 0.005950982339533779,
#  (731587, 73158): 0.005284951358727224,
#  (546197, 273098): -2.5822728705027327e-05,
#  (599783, 59978): 0.018715492302559998,
#  (121019, 1210): -0.06293951534515212,
#  (555953, 55595): -0.010212074846537527,
#  (622397, 5): 5.2463747735072424e-06,
#  (611069, 5): -0.00038894753016402786,
#  (582203, 58220): 0.010785158429482309,
#  (584027, 292013): 3.068928227959738e-06,
#  (635279, 317639): -2.8528048225257103e-05,
#  (526373, 5263): -0.037715108376165894,
#  (593323, 118664): 0.006692197144530924,
#  (131687, 5): 0.00036680908216700823,
#  (601541, 300770): 1.0383320688067563e-05,
#  (673427, 5): -0.00020988110985109632,
#  (640499, 6404): 0.019132416354392598,
#  (582203, 5822): 0.018586602342208207,
#  (537703, 5377): 0.018059426339359853,
#  (131687, 13168): 0.02599557584317465,
#  (602257, 5): 1.7072594000036992e-05,
#  (178141, 35628): 0.016960657079663325,
#  (731587, 7315): -0.03638751995935568,
#  (508393, 101678): 0.00919734305435749,
#  (131687, 26337): -0.10995567264629276,
#  (562669, 112533): 0.001216906333215132,
#  (746477, 5): -0.00018110550628699213,
#  (642769, 5): 0.00024958104412404266,
#  (562669, 281334): -5.240139832796466e-06,
#  (593323, 59332): -0.01140262974787524,
#  (739633, 147926): -0.027778295537914867,
#  (671651, 335825): 7.647844882170613e-06,
#  (508393, 254196): -5.719978804419818e-06,
#  (599783, 5997): 0.013882218948409663,
#  (544937, 54493): 0.00714131391867072,
#  (624521, 5): -0.00011394045937261736,
#  (624521, 312260): -4.2202946363106194e-05,
#  (611069, 61106): 0.03730595200400173,
#  (622397, 6223): -0.00021838738736981974,
#  (639049, 5): 6.235766236002556e-05,
#  (121019, 60509): -0.00013551414737271642,
#  (526373, 52637): -0.02183219736822559,
#  (537703, 107540): -0.012343409963152594,
#  (731587, 146317): -0.007000511074818902,
#  (544903, 54490): -0.03092225501101825,
#  (546197, 54619): -0.0019377134128888366,
#  (511279, 5112): 0.010709376081047668,
#  (639533, 127906): 0.009627423070972401,
#  (635279, 6352): 0.00644922165450243,
#  (546197, 5): 0.00014148738262552776,
#  (537703, 5): -0.00029751349751891627,
#  (508393, 50839): 0.009660235466792342,
#  (584027, 5): -0.00031167563617750144,
#  (643873, 64387): 0.004397671065990627,
#  (599783, 299891): 1.7408730845503846e-05,
#  (584027, 116805): -0.026658775728135357,
#  (178141, 17814): -0.0014721560827152486,
#  (673427, 6734): -0.0070610465554455494,
#  (511279, 51127): 0.008085692165180017,
#  (640499, 64049): 0.013903587754180253,
#  (511279, 255639): -2.272083617333342e-05,
#  (639049, 6390): 0.02435755630368866,
#  (602257, 120451): -0.013326098733429955,
#  (584027, 58402): -0.0022492491735826596,
#  (746477, 373238): -1.125219267764878e-05,
#  (602257, 60225): -0.021716666249626877,
#  (593323, 5933): 0.015270504506463537,
#  (714619, 71461): -0.012123803128698771,
#  (602257, 6022): 0.02782630010958253,
#  (601541, 120308): 0.014215482924406091,
#  (526373, 5): -0.00011500227438241564,
#  (599783, 5): 0.0002606547343230765,
#  (599783, 119956): -0.014950298129872018,
#  (582203, 5): 0.0002845719766013273,
#  (714619, 7146): 0.0018494136068104377,
#  (622397, 62239): 0.0002407750535514873,
#  (178141, 5): -0.0009517524423274992,
#  (739633, 5): -8.395699777480802e-06,
#  (601541, 6015): 0.015023069000200874,
#  (526373, 263186): -2.3017441407172552e-05,
#  (639533, 5): 0.00014901913578407763,
#  (622397, 124479): -0.0034751877675033536,
#  (562669, 5626): 0.0033482138415002237,
#  (639533, 6395): -0.0059963297210421105,
#  (555953, 277976): 7.017841559229119e-06,
#  (673427, 336713): -6.8444813520383956e-06,
#  (671651, 6716): -0.040445593331944564,
#  (671651, 67165): 2.366937285963214e-06,
#  (739633, 369816): 1.82045830769125e-05,
#  (671651, 5): -3.264653447583139e-05,
#  (544903, 272451): 7.169910947301964e-06,
#  (731587, 365793): -1.0814253651814888e-05,
#  (121019, 5): -0.0025846540342165684,
#  (602257, 301128): 2.246381110689338e-05,
#  (562669, 5): 2.3815033223860183e-06,
#  (746477, 74647): -0.01778164763787142,
#  (508393, 5083): 0.06419549081021406}

# %%
sym_lst = symmetry_dict[(640499, 128099)]
cons, terms = sym_lst[0], sym_lst[1:]

for (leg, alt, sin1, sin2, ninv) in terms:
    print(f"=" * 15)
    print(f"legendre: {leg}, alt: {alt}, prod: {alt * leg}")
    print(f"sin(pi n/p): {sin1}, sin(2pi n d/p): {sin2}, prod = {sin1 *sin2*ninv}")
# Out:
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 4.90491422090776e-06, sin(2pi n d/p): 0.951054091142906, prod = 4.664838736499344e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 9.80982844169751e-06, sin(2pi n d/p): 0.587797950328745, prod = 2.8830985255532116e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 1.47147426622513e-05, sin(2pi n d/p): -0.587766204966559, prod = -2.882942817216989e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 1.9619656882451e-05, sin(2pi n d/p): -0.951066216318397, prod = -4.664898209164467e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 2.45245711021787e-05, sin(2pi n d/p): -3.92393137573498e-05, prod = -1.9246546804856478e-10
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 2.94294853213164e-05, sin(2pi n d/p): 0.951041964503055, prod = 4.6647792557164285e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 3.43343995397461e-05, sin(2pi n d/p): 0.587829694785884, prod = 2.8832542288722207e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 3.92393137573498e-05, sin(2pi n d/p): -0.587734458699375, prod = -2.8827871038638657e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 4.41442279740094e-05, sin(2pi n d/p): -0.951078340029508, prod = -4.66495767371167e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 4.9049142189607e-05, sin(2pi n d/p): -7.84786274542818e-05, prod = -3.849309356850264e-10
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 5.39540564040246e-05, sin(2pi n d/p): 0.951029836398861, prod = 4.664719766815857e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 5.88589706171441e-05, sin(2pi n d/p): 0.587861438337928, prod = 2.8834099271736806e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 6.37638848288476e-05, sin(2pi n d/p): -0.587702711527243, prod = -2.882631385494197e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 6.86687990390171e-05, sin(2pi n d/p): -0.951090462276222, prod = -4.665017130140839e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 7.35737132475345e-05, sin(2pi n d/p): -0.000117717941030378, prod = -5.773964024972804e-10
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 7.84786274542818e-05, sin(2pi n d/p): 0.951017706830345, prod = 4.664660269797752e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 8.33835416591411e-05, sin(2pi n d/p): 0.587893180984828, prod = 2.8835656204572576e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 8.82884558619944e-05, sin(2pi n d/p): -0.587670963450211, prod = -2.882475662108315e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 9.31933700627236e-05, sin(2pi n d/p): -0.951102583058519, prod = -4.665076578451835e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 9.80982842612107e-05, sin(2pi n d/p): -0.000156957254425222, prod = -7.698618680732299e-10
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000103003198457338, sin(2pi n d/p): 0.951005575797524, prod = 4.664600764662255e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000107908112650987, sin(2pi n d/p): 0.587924922726535, prod = 2.8837213087226256e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.00011281302684204, sin(2pi n d/p): -0.587639214468328, prod = -2.8823199337065565e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000117717941030378, sin(2pi n d/p): -0.951114702376381, prod = -4.665136018644514e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000122622855215885, sin(2pi n d/p): -0.000196196567578395, prod = -9.62327332000765e-10
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000127527769398442, sin(2pi n d/p): 0.950993443300417, prod = 4.664541251409459e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.00013243268357793, sin(2pi n d/p): 0.587956663563, prod = 2.8838769919694158e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000137337597754233, sin(2pi n d/p): -0.587607464581643, prod = -2.8821642002892286e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000142242511927231, sin(2pi n d/p): -0.951126820229789, prod = -4.665195450718795e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000147147426096808, sin(2pi n d/p): -0.000235435880429479, prod = -1.1547927938677895e-09
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000152052340262844, sin(2pi n d/p): 0.950981309339043, prod = 4.664481730039519e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000156957254425222, sin(2pi n d/p): 0.587988403494173, prod = 2.884032670197344e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000161862168583824, sin(2pi n d/p): -0.587575713790205, prod = -2.882008461856693e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000166767082738532, sin(2pi n d/p): -0.951138936618725, prod = -4.665254874674537e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000171671996889228, sin(2pi n d/p): -0.000274675192918057, prod = -1.3472582532621938e-09
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000176576911035793, sin(2pi n d/p): 0.95096917391342, prod = 4.6644222005525414e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000181481825178111, sin(2pi n d/p): 0.588020142520008, prod = 2.8841883434060545e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000186386739316062, sin(2pi n d/p): -0.587543962094063, prod = -2.881852718409272e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.00019129165344953, sin(2pi n d/p): -0.951151051543169, prod = -4.665314290511588e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000196196567578395, sin(2pi n d/p): -0.000313914504983711, prod = -1.5397237097718765e-09
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.00020110148170254, sin(2pi n d/p): 0.950957037023568, prod = 4.664362662948701e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000206006395821847, sin(2pi n d/p): 0.588051880640453, prod = 2.884344011595207e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000210911309936197, sin(2pi n d/p): -0.587512209493265, prod = -2.8816969699473007e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000215816224045474, sin(2pi n d/p): -0.951163165003103, prod = -4.665373698229815e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000220721138149559, sin(2pi n d/p): -0.000353153816566024, prod = -1.732189162984742e-09
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000225626052248333, sin(2pi n d/p): 0.950944898669504, prod = 4.664303117228071e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000230530966341679, sin(2pi n d/p): 0.588083617855462, prod = 2.884499674764475e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000235435880429479, sin(2pi n d/p): -0.587480455987861, prod = -2.8815412164711217e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000240340794511615, sin(2pi n d/p): -0.951175276998509, prod = -4.6654330978291245e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000245245708587968, sin(2pi n d/p): -0.000392393127604577, prod = -1.9246546124886684e-09
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000250150622658422, sin(2pi n d/p): 0.950932758851248, prod = 4.664243563390798e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000255055536722857, sin(2pi n d/p): 0.588115354164984, prod = 2.8846553329135215e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000259960450781156, sin(2pi n d/p): -0.587448701577899, prod = -2.881385457981045e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000264865364833201, sin(2pi n d/p): -0.951187387529368, prod = -4.665492489309359e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000269770278878874, sin(2pi n d/p): -0.000431632438038953, prod = -2.1171200578715754e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000274675192918057, sin(2pi n d/p): 0.950920617568818, prod = 4.664184001437017e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000279580106950631, sin(2pi n d/p): 0.58814708956897, prod = 2.8848109860420172e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.00028448502097648, sin(2pi n d/p): -0.587416946263428, prod = -2.8812296944774335e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000289389934995484, sin(2pi n d/p): -0.951199496595661, prod = -4.665551872670431e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000294294849007526, sin(2pi n d/p): -0.000470871747808734, prod = -2.309585498721354e-09
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000299199763012487, sin(2pi n d/p): 0.950908474822233, prod = 4.664124431366846e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000304104677010251, sin(2pi n d/p): 0.588178824067373, prod = 2.88496663414964e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000309009591000698, sin(2pi n d/p): -0.587385190044498, prod = -2.8810739259605963e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000313914504983711, sin(2pi n d/p): -0.951211604197369, prod = -4.665611247912168e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000318819418959172, sin(2pi n d/p): -0.000510111056853503, prod = -2.502050934625892e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000323724332926963, sin(2pi n d/p): 0.950896330611512, prod = 4.6640648531804335e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000328629246886965, sin(2pi n d/p): 0.588210557660143, prod = 2.885122277236037e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000333534160839061, sin(2pi n d/p): -0.587353432921156, prod = -2.880918152430875e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000338439074783133, sin(2pi n d/p): -0.951223710334475, prod = -4.6656706150344724e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000343343988719063, sin(2pi n d/p): -0.000549350365112842, prod = -2.6945163651730964e-09
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000348248902646732, sin(2pi n d/p): 0.950884184936673, prod = 4.664005266877867e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000353153816566024, sin(2pi n d/p): 0.588242290347231, prod = 2.8852779153008866e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000358058730476819, sin(2pi n d/p): -0.587321674893453, prod = -2.8807623738886136e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000362963644378999, sin(2pi n d/p): -0.951235815006958, prod = -4.6657299740372e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000367868558272448, sin(2pi n d/p): -0.000588589672526333, prod = -2.8869817899508587e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000372773472157046, sin(2pi n d/p): 0.950872037797736, prod = 4.663945672459315e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000377678386032676, sin(2pi n d/p): 0.588274022128588, prod = 2.8854335483438425e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.00038258329989922, sin(2pi n d/p): -0.587289915961437, prod = -2.8806065903341303e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000387488213756559, sin(2pi n d/p): -0.951247918214801, prod = -4.665789324920235e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000392393127604577, sin(2pi n d/p): -0.000627828979033559, prod = -3.079447208547083e-09
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000397298041443154, sin(2pi n d/p): 0.950859889194718, prod = 4.663886069924887e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000402202955272172, sin(2pi n d/p): 0.588305753004166, prod = 2.8855891763645863e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000407107869091515, sin(2pi n d/p): -0.587258156125156, prod = -2.880450801767765e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000412012782901063, sin(2pi n d/p): -0.951260019957986, prod = -4.665848667683459e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000416917696700699, sin(2pi n d/p): -0.000667068284574101, prod = -3.2719126205496547e-09
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000421822610490304, sin(2pi n d/p): 0.950847739127638, prod = 4.663826459274696e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000426727524269762, sin(2pi n d/p): 0.588337482973916, prod = 2.8857447993627865e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000431632438038953, sin(2pi n d/p): -0.58722639538466, prod = -2.8802950081898517e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.00043653735179776, sin(2pi n d/p): -0.951272120236492, prod = -4.665908002326725e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000441442265546064, sin(2pi n d/p): -0.000706307589087543, prod = -3.4643780255464824e-09
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000446347179283748, sin(2pi n d/p): 0.950835587596516, prod = 4.663766840508902e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000451252093010694, sin(2pi n d/p): 0.588369212037788, prod = 2.8859004173380944e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000456157006726784, sin(2pi n d/p): -0.587194633739997, prod = -2.8801392096007234e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000461061920431899, sin(2pi n d/p): -0.951284219050303, prod = -4.6659673288499145e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000465966834125922, sin(2pi n d/p): -0.000745546892513466, prod = -3.6568434231254613e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000470871747808734, sin(2pi n d/p): 0.950823434601369, prod = 4.6637072136276045e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000475776661480218, sin(2pi n d/p): 0.588400940195735, prod = 2.8860560302901873e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000480681575140256, sin(2pi n d/p): -0.587162871191217, prod = -2.8799834060007082e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.00048558648878873, sin(2pi n d/p): -0.951296316399398, prod = -4.666026647252894e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000490491402425521, sin(2pi n d/p): -0.000784786194791453, prod = -3.849308812874479e-09
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000495396316050512, sin(2pi n d/p): 0.950811280142217, prod = 4.663647578630947e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000500301229663585, sin(2pi n d/p): 0.588432667447706, prod = 2.886211638218732e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000505206143264621, sin(2pi n d/p): -0.587131107738369, prod = -2.8798275973901556e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000510111056853503, sin(2pi n d/p): -0.95130841228376, prod = -4.666085957535546e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000515015970430113, sin(2pi n d/p): -0.000824025495861085, prod = -4.041774194381445e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000519920883994332, sin(2pi n d/p): 0.950799124219078, prod = 4.663587935519054e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000524825797546043, sin(2pi n d/p): 0.588464393793654, prod = 2.886367241123394e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000529730711085128, sin(2pi n d/p): -0.5870993433815, prod = -2.8796717837693867e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000534635624611468, sin(2pi n d/p): -0.95132050670337, prod = -4.666145259697748e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000539540538124946, sin(2pi n d/p): -0.000863264795661947, prod = -4.234239567234258e-09
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000544445451625443, sin(2pi n d/p): 0.950786966831972, prod = 4.6635282842920544e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000549350365112842, sin(2pi n d/p): 0.588496119233529, prod = 2.8865228390038364e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000554255278587025, sin(2pi n d/p): -0.587067578120661, prod = -2.879515965138735e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000559160192047873, sin(2pi n d/p): -0.951332599658209, prod = -4.666204553739354e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000564065105495269, sin(2pi n d/p): -0.000902504094133618, prod = -4.426704931020795e-09
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000568970018929095, sin(2pi n d/p): 0.950774807980916, prod = 4.663468624950072e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000573874932349232, sin(2pi n d/p): 0.588527843767283, prod = 2.8866784318597347e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000578779845755563, sin(2pi n d/p): -0.5870358119559, prod = -2.8793601414985382e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000583684759147969, sin(2pi n d/p): -0.951344691148258, prod = -4.666263839660251e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000588589672526333, sin(2pi n d/p): -0.000941743391215683, prod = -4.619170285328975e-09
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000593494585890537, sin(2pi n d/p): 0.950762647665929, prod = 4.663408957493232e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000598399499240462, sin(2pi n d/p): 0.588559567394866, prod = 2.8868340196907447e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000603304412575991, sin(2pi n d/p): -0.587004044887266, prod = -2.8792043128491275e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000608209325897005, sin(2pi n d/p): -0.9513567811735, prod = -4.666323117460314e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000613114239203387, sin(2pi n d/p): -0.000980982686847723, prod = -4.8116356297466895e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000618019152495019, sin(2pi n d/p): 0.950750485887031, prod = 4.66334928192167e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000622924065771782, sin(2pi n d/p): 0.58859129011623, prod = 2.886989602496539e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000627828979033559, sin(2pi n d/p): -0.586972276914808, prod = -2.8790484791908387e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000632733892280231, sin(2pi n d/p): -0.951368869733915, prod = -4.666382387139412e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000637638805511681, sin(2pi n d/p): -0.00102022198096932, prod = -5.004100963861832e-09
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000642543718727791, sin(2pi n d/p): 0.95073832264424, prod = 4.663289598235514e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000647448631928442, sin(2pi n d/p): 0.588623011931326, prod = 2.887145180276788e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000652353545113516, sin(2pi n d/p): -0.586940508038575, prod = -2.8788926405240043e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000657258458282896, sin(2pi n d/p): -0.951380956829485, prod = -4.666441648697415e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000662163371436464, sin(2pi n d/p): -0.00105946127352006, prod = -5.196566287262315e-09
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000667068284574101, sin(2pi n d/p): 0.950726157937574, prod = 4.663229906434877e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.00067197319769569, sin(2pi n d/p): 0.588654732840106, prod = 2.8873007530311547e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000676878110801113, sin(2pi n d/p): -0.586908738258615, prod = -2.8787367968489584e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.00068178302389025, sin(2pi n d/p): -0.951393042460191, prod = -4.666500902134201e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000686687936962986, sin(2pi n d/p): -0.00109870056443952, prod = -5.389031599536016e-09
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000691592850019201, sin(2pi n d/p): 0.950713991767052, prod = 4.663170206519905e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000696497763058777, sin(2pi n d/p): 0.58868645284252, prod = 2.8874563207593056e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000701402676081597, sin(2pi n d/p): -0.586876967574979, prod = -2.8785809481660343e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000706307589087543, sin(2pi n d/p): -0.951405126626014, prod = -4.666560147449642e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000711212502076496, sin(2pi n d/p): -0.00113793985366728, prod = -5.581496900270813e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000716117415048339, sin(2pi n d/p): 0.950701824132694, prod = 4.663110498490722e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000721022328002953, sin(2pi n d/p): 0.588718171938519, prod = 2.8876118834609097e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.00072592724094022, sin(2pi n d/p): -0.586845195987713, prod = -2.8784250944755624e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000730832153860023, sin(2pi n d/p): -0.951417209326936, prod = -4.666619384643604e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000735737066762244, sin(2pi n d/p): -0.00117717914114294, prod = -5.773962189054696e-09
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000740641979646764, sin(2pi n d/p): 0.950689655034518, prod = 4.663050782347448e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000745546892513466, sin(2pi n d/p): 0.588749890128055, prod = 2.8877674411356312e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000750451805362231, sin(2pi n d/p): -0.586813423496869, prod = -2.878269235777888e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000755356718192942, sin(2pi n d/p): -0.951429290562939, prod = -4.666678613715978e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.00076026163100548, sin(2pi n d/p): -0.00121641842680606, prod = -5.966427465475453e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000765166543799727, sin(2pi n d/p): 0.950677484472542, prod = 4.662991058090215e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000770071456575566, sin(2pi n d/p): 0.588781607411078, prod = 2.887922993783133e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000774976369332879, sin(2pi n d/p): -0.586781650102494, prod = -2.878113372073332e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000779881282071547, sin(2pi n d/p): -0.951441370334004, prod = -4.66673783466662e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000784786194791453, sin(2pi n d/p): -0.00125565771059623, prod = -6.158892729121018e-09
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000789691107492478, sin(2pi n d/p): 0.950665312446785, prod = 4.662931325719157e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000794596020174504, sin(2pi n d/p): 0.588813323787541, prod = 2.8880785414030965e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000799500932837414, sin(2pi n d/p): -0.586749875804637, prod = -2.8779575033622336e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000804405845481089, sin(2pi n d/p): -0.951453448640111, prod = -4.666797047495405e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000809310758105412, sin(2pi n d/p): -0.00129489699245304, prod = -6.3513579795793195e-09
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000814215670710264, sin(2pi n d/p): 0.950653138957266, prod = 4.662871585234386e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000819120583295528, sin(2pi n d/p): 0.588845039257394, prod = 2.8882340839951775e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000824025495861085, sin(2pi n d/p): -0.586718100603347, prod = -2.8778016296449217e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000828930408406818, sin(2pi n d/p): -0.951465525481243, prod = -4.666856252202215e-06
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000833835320932608, sin(2pi n d/p): -0.00133413627231606, prod = -6.543823216438207e-09
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000838740233438337, sin(2pi n d/p): 0.950640964004005, prod = 4.662811836636051e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000843645145923888, sin(2pi n d/p): 0.588876753820588, prod = 2.888389621559043e-06
# ===============
# legendre: -1, alt: -1, prod: 1
# sin(pi n/p): 0.000848550058389143, sin(2pi n d/p): -0.586686324498674, prod = -2.877645750921743e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000853454970833983, sin(2pi n d/p): -0.951477600857381, prod = -4.66691544878692e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.00085835988325829, sin(2pi n d/p): -0.00137337555012488, prod = -6.736288439285611e-09
# ===============
# legendre: 1, alt: 1, prod: 1
# sin(pi n/p): 0.000863264795661947, sin(2pi n d/p): 0.950628787587018, prod = 4.66275207992427e-06
# ===============
# legendre: 1, alt: -1, prod: -1
# sin(pi n/p): 0.000868169708044835, sin(2pi n d/p): 0.588908467477075, prod = 2.8885451540943697e-06
# ===============
# legendre: -1, alt: 1, prod: -1
# sin(pi n/p): 0.000873074620406836, sin(2pi n d/p): -0.586654547490665, prod = -2.8774898671930144e-06
